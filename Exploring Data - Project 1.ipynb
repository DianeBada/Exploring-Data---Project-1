# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movies_df = pd.read_csv(r'C:\Users\ogedi\Downloads\archive\TMBD Movie Dataset.csv')

# %%
movies_df

#data shows 1287 different movies 
# it also shows, populairy, rvenue, orignal title, cast, vote count, relsease year, budget, revenue, profit
# Out:
#       Unnamed: 0      id    imdb_id  popularity       budget       revenue  \
# 0              0  135397  tt0369610   32.985763  150000000.0  1.513529e+09
# 1              1   76341  tt1392190   28.419936  150000000.0  3.784364e+08
# 2              2  262500  tt2908446   13.112507  110000000.0  2.952382e+08
# 3              3  140607  tt2488496   11.173104  200000000.0  2.068178e+09
# 4              4  168259  tt2820852    9.335014  190000000.0  1.506249e+09
# ...          ...     ...        ...         ...          ...           ...
# 1282       10595     253  tt0070328    1.549139    7000000.0  1.617778e+08
# 1283       10689     660  tt0059800    1.910465   11000000.0  1.411957e+08
# 1284       10724     668  tt0064757    1.778746    7000000.0  8.197449e+07
# 1285       10759     948  tt0077651    1.198849     300000.0  7.000000e+07
# 1286       10760    8469  tt0077975    1.157930    2700000.0  1.410000e+08
#
#                        original_title  \
# ...

# %%
# shape of data 
movies_df.shape
# Out:
# (1287, 24)

# %%
# display top 10 rows of the dataset 

movies_df.head(10)
# Out:
#    Unnamed: 0      id    imdb_id  popularity       budget       revenue  \
# 0           0  135397  tt0369610   32.985763  150000000.0  1.513529e+09
# 1           1   76341  tt1392190   28.419936  150000000.0  3.784364e+08
# 2           2  262500  tt2908446   13.112507  110000000.0  2.952382e+08
# 3           3  140607  tt2488496   11.173104  200000000.0  2.068178e+09
# 4           4  168259  tt2820852    9.335014  190000000.0  1.506249e+09
# 5           5  281957  tt1663202    9.110700  135000000.0  5.329505e+08
# 6           6   87101  tt1340138    8.654359  155000000.0  4.406035e+08
# 7           7  286217  tt3659388    7.667400  108000000.0  5.953803e+08
# 8           8  211672  tt2293640    7.404165   74000000.0  1.156731e+09
# 9           9  150540  tt2096673    6.326804  175000000.0  8.537086e+08
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# ...

# %%
#display last 10 rows 
movies_df.tail(10)
# Out:
#       Unnamed: 0    id    imdb_id  popularity      budget      revenue  \
# 1277       10338  8291  tt0107840    0.313792  14000000.0   27515786.0
# 1278       10401   667  tt0062512    1.554808   9500000.0  111584787.0
# 1279       10438   657  tt0057076    2.508235   2500000.0   78898765.0
# 1280       10489  6978  tt0090728    0.960984  25000000.0   11000000.0
# 1281       10594  9552  tt0070047    2.010733   8000000.0  441306145.0
# 1282       10595   253  tt0070328    1.549139   7000000.0  161777836.0
# 1283       10689   660  tt0059800    1.910465  11000000.0  141195658.0
# 1284       10724   668  tt0064757    1.778746   7000000.0   81974493.0
# 1285       10759   948  tt0077651    1.198849    300000.0   70000000.0
# 1286       10760  8469  tt0077975    1.157930   2700000.0  141000000.0
#
#                        original_title  \
# 1277                   Poetic Justice
# 1278              You Only Live Twice
# 1279            From Russia With Love
# ...

# %%
#information on the dataset 
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1287 entries, 0 to 1286
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            1287 non-null   int64
#  1   id                    1287 non-null   int64
#  2   imdb_id               1287 non-null   object
#  3   popularity            1287 non-null   float64
#  4   budget                1287 non-null   float64
#  5   revenue               1287 non-null   float64
#  6   original_title        1287 non-null   object
#  7   cast                  1287 non-null   object
#  8   homepage              1287 non-null   object
#  9   director              1287 non-null   object
#  10  tagline               1287 non-null   object
#  11  keywords              1287 non-null   object
#  12  overview              1287 non-null   object
#  13  runtime               1287 non-null   int64
#  14  genres                1287 non-null   object
# ...

# %%
#is there any missing values in the missing values, 

print("any missing values?", movies_df.isnull().values.any())
# Out:
# any missing values? True

# %%
# which coloumns have missing values?
movies_df.isnull().sum()
# Out:
# Unnamed: 0              0
# id                      0
# imdb_id                 0
# popularity              0
# budget                  0
# revenue                 0
# original_title          0
# cast                    0
# homepage                0
# director                0
# tagline                 0
# keywords                0
# overview                0
# runtime                 0
# genres                  0
# production_companies    0
# release_date            0
# vote_count              0
# vote_average            0
# release_year            0
# budget_adj              0
# revenue_adj             0
# profit                  0
# popularity_level        1
# dtype: int64

# %%
sns.heatmap(movies_df.isnull())

# just one missing value in popularity level
# Out:
# <AxesSubplot: >

# %%
# lets drop all the missing values 
# axis = 0  means drop rows that contain missing values
#axis = 1 means drop coloumns that contain missing values
movies_df.dropna(axis=0)
# Out:
#       Unnamed: 0      id    imdb_id  popularity       budget       revenue  \
# 0              0  135397  tt0369610   32.985763  150000000.0  1.513529e+09
# 1              1   76341  tt1392190   28.419936  150000000.0  3.784364e+08
# 2              2  262500  tt2908446   13.112507  110000000.0  2.952382e+08
# 3              3  140607  tt2488496   11.173104  200000000.0  2.068178e+09
# 4              4  168259  tt2820852    9.335014  190000000.0  1.506249e+09
# ...          ...     ...        ...         ...          ...           ...
# 1282       10595     253  tt0070328    1.549139    7000000.0  1.617778e+08
# 1283       10689     660  tt0059800    1.910465   11000000.0  1.411957e+08
# 1284       10724     668  tt0064757    1.778746    7000000.0  8.197449e+07
# 1285       10759     948  tt0077651    1.198849     300000.0  7.000000e+07
# 1286       10760    8469  tt0077975    1.157930    2700000.0  1.410000e+08
#
#                        original_title  \
# ...

# %%
# check for duplicate data 

duplicate_data = movies_df.duplicated().any()

# %%
print('Are there any duplicated values?', duplicate_data)

#means there is no duplicate values
# Out:
# Are there any duplicated values? False

# %%
# if there were, we could drop them by using ---
# data = movies_df.drop_duplicates()`````````

# %%
# Get overall statistics 

movies_df.describe( )
# Out:
#          Unnamed: 0             id   popularity        budget       revenue  \
# count   1287.000000    1287.000000  1287.000000  1.287000e+03  1.287000e+03
# mean    4125.843046   52557.491064     1.786022  5.200349e+07  1.762444e+08
# std     2671.936574   74450.077163     2.172137  5.514540e+07  2.538156e+08
# min        0.000000      11.000000     0.010335  1.000000e+00  4.300000e+01
# 25%     1972.000000    5851.500000     0.664783  1.400000e+07  2.565097e+07
# 50%     3523.000000   20178.000000     1.152354  3.200000e+07  8.208716e+07
# 75%     6554.500000   62209.500000     2.125342  7.000000e+07  2.140694e+08
# max    10760.000000  333348.000000    32.985763  4.250000e+08  2.781506e+09
#
#            runtime   vote_count  vote_average  release_year    budget_adj  \
# count  1287.000000  1287.000000   1287.000000   1287.000000  1.287000e+03
# mean    110.273504   947.266511      6.279487   2007.017094  5.462994e+07
# ...

# %%
# display coloumn names 

movies_df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'imdb_id', 'popularity', 'budget', 'revenue',
#        'original_title', 'cast', 'homepage', 'director', 'tagline', 'keywords',
#        'overview', 'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj', 'profit', 'popularity_level'],
#       dtype='object')

# %%
## lets display title of movie having runtime bigger or equal to 180 minutes

movies_df[ movies_df['runtime'] >=180]['original_title']
# Out:
# 418                                    The Green Mile
# 431                                          Magnolia
# 808     The Lord of the Rings: The Return of the King
# 838                                           Titanic
# 851                           The Wolf of Wall Street
# 1271                                 Schindler's List
# Name: original_title, dtype: object

# %%
## In which year was the highest average voting`b`b`b

# %%
movies_df.groupby('release_year')['vote_count'].mean().sort_values(ascending = False)
# Out:
# release_year
# 1972    3970.000000
# 1977    2353.500000
# 1980    2041.000000
# 1985    2028.500000
# 2013    1651.261538
# 1982    1579.000000
# 2012    1531.852273
# 2014    1524.085714
# 1984    1475.250000
# 1997    1395.375000
# 2015    1322.021505
# 1999    1310.500000
# 2001    1276.222222
# 1995    1258.125000
# 1989    1256.000000
# 1990    1162.500000
# 2002    1143.083333
# 1979    1043.250000
# 1993     948.285714
# 1975     948.000000
# 2003     934.666667
# 1998     874.272727
# 1991     873.500000
# 1994     871.200000
# 2004     832.534884
# 1983     778.000000
# 2008     751.353659
# 2010     739.121212
# 2009     722.534483
# 2011     714.839744
# 1973     703.000000
# 1981     644.333333
# 2007     641.836957
# 1992     638.400000
# 2005     591.235294
# 2006     576.250000
# 1962     560.000000
# 1996     558.692308
# 2000     538.000000
# 1963     458.000000
# 1978     376.000000
# 1987     362.500000
# 1964     347.000000
# 1986     347.000000
# ...

# %%
sns.barplot(x= 'release_year', y='vote_count', data = movies_df)
plt.title("Votes By Year")
plt.show()

# %%
movies_df
# Out:
#       Unnamed: 0      id    imdb_id  popularity       budget       revenue  \
# 0              0  135397  tt0369610   32.985763  150000000.0  1.513529e+09
# 1              1   76341  tt1392190   28.419936  150000000.0  3.784364e+08
# 2              2  262500  tt2908446   13.112507  110000000.0  2.952382e+08
# 3              3  140607  tt2488496   11.173104  200000000.0  2.068178e+09
# 4              4  168259  tt2820852    9.335014  190000000.0  1.506249e+09
# ...          ...     ...        ...         ...          ...           ...
# 1282       10595     253  tt0070328    1.549139    7000000.0  1.617778e+08
# 1283       10689     660  tt0059800    1.910465   11000000.0  1.411957e+08
# 1284       10724     668  tt0064757    1.778746    7000000.0  8.197449e+07
# 1285       10759     948  tt0077651    1.198849     300000.0  7.000000e+07
# 1286       10760    8469  tt0077975    1.157930    2700000.0  1.410000e+08
#
#                        original_title  \
# ...

# %%
## find average rating for each director using voting average 

movies_df.groupby('director')['vote_average'].mean().sort_values(ascending = False).head(20)
# Out:
# director
# Damien Chazelle                   8.200000
# Pete Docter                       8.000000
# Morten Tyldum                     8.000000
# Lenny Abrahamson                  8.000000
# Tony Kaye                         8.000000
# Richard Marquand                  7.800000
# Lucy Walker                       7.800000
# Rajkumar Hirani                   7.800000
# Don Hall|Chris Williams           7.800000
# Denis Villeneuve                  7.800000
# Lilly Wachowski|Lana Wachowski    7.800000
# Christopher Nolan                 7.785714
# Giuseppe Tornatore                7.700000
# Sean Penn                         7.700000
# Roger Allers|Rob Minkoff          7.700000
# Dean DeBlois                      7.700000
# Stephen Chbosky                   7.600000
# Mark Herman                       7.600000
# Joel Coen                         7.600000
# Joe Russo|Anthony Russo           7.600000
# Name: vote_average, dtype: float64

# %%
## Display Top 10 Lengthy Movies and Titles

#using nlargest - returns the 'n' rows orderded by colomns in descending order 
#set_index -- which coloum starts first
top10_m = movies_df.nlargest(10, 'runtime') [['original_title', 'runtime']].set_index('original_title')

# %%
top10_m
# Out:
#                                                    runtime
# original_title
# The Lord of the Rings: The Return of the King          201
# Schindler's List                                       195
# Titanic                                                194
# The Green Mile                                         189
# Magnolia                                               188
# The Wolf of Wall Street                                180
# The Lord of the Rings: The Two Towers                  179
# The Lord of the Rings: The Fellowship of the Ring      178
# Meet Joe Black                                         178
# The Godfather                                          175

# %%
sns.barplot(x = 'runtime', y = top10_m.index, data = top10_m)
plt.title("Average Rating for Directors")
# Out:
# Text(0.5, 1.0, 'Average Rating for Directors')

# %%
##Display Number of Movies per Year

movies_per_year = movies_df['release_year'].value_counts()
movies_per_year
# Out:
# 2011    156
# 2010    132
# 2009    116
# 2015     93
# 2007     92
# 2012     88
# 2008     82
# 2014     70
# 2006     68
# 2013     65
# 2005     51
# 2004     43
# 2003     30
# 2002     24
# 1999     22
# 2001     18
# 2000     14
# 1996     13
# 1998     11
# 1995      8
# 1997      8
# 1993      7
# 1981      6
# 1983      5
# 1992      5
# 1994      5
# 1987      4
# 1979      4
# 1984      4
# 1989      4
# 1990      4
# 1971      4
# 1975      3
# 1982      3
# 1973      2
# 1964      2
# 1980      2
# 1988      2
# 1991      2
# 1977      2
# 1985      2
# 1978      2
# 1974      1
# 1962      1
# 1972      1
# 1961      1
# 1967      1
# 1963      1
# 1986      1
# 1965      1
# 1969      1
# Name: release_year, dtype: int64

# %%
sns.countplot(x='release_year', data = movies_df)
plt.rcParams["figure.figsize"] = [21.50, 21.10]

# %%
### Find most popular movie title (highest revenue)

movies_df[movies_df['revenue'].max() == movies_df ['revenue']] ['original_title']
# Out:
# 165    Avatar
# Name: original_title, dtype: object

# %%
## Display top 10 highest rated movie titles and its directors 

top10_rated = movies_df.nlargest(10, "vote_count")[['original_title', 'director', 'vote_count']].set_index('original_title')
top10_rated
# Out:
#                                             director  vote_count
# original_title
# Inception                          Christopher Nolan        9767
# The Avengers                             Joss Whedon        8903
# Avatar                                 James Cameron        8458
# The Dark Knight                    Christopher Nolan        8432
# Django Unchained                   Quentin Tarantino        7375
# The Hunger Games                           Gary Ross        7080
# Iron Man 3                               Shane Black        6882
# The Dark Knight Rises              Christopher Nolan        6723
# Interstellar                       Christopher Nolan        6498
# The Hobbit: An Unexpected Journey      Peter Jackson        6417

# %%
movies_df
# Out:
#       Unnamed: 0      id    imdb_id  popularity       budget       revenue  \
# 0              0  135397  tt0369610   32.985763  150000000.0  1.513529e+09
# 1              1   76341  tt1392190   28.419936  150000000.0  3.784364e+08
# 2              2  262500  tt2908446   13.112507  110000000.0  2.952382e+08
# 3              3  140607  tt2488496   11.173104  200000000.0  2.068178e+09
# 4              4  168259  tt2820852    9.335014  190000000.0  1.506249e+09
# ...          ...     ...        ...         ...          ...           ...
# 1282       10595     253  tt0070328    1.549139    7000000.0  1.617778e+08
# 1283       10689     660  tt0059800    1.910465   11000000.0  1.411957e+08
# 1284       10724     668  tt0064757    1.778746    7000000.0  8.197449e+07
# 1285       10759     948  tt0077651    1.198849     300000.0  7.000000e+07
# 1286       10760    8469  tt0077975    1.157930    2700000.0  1.410000e+08
#
#                        original_title  \
# ...

# %%
sns.barplot(x = 'vote_count', y = top10_rated.index,  data = top10_rated, hue = 'director', dodge = False)
plt.legend(bbox_to_anchor=(1.05, 1), loc =2, prop = {'size':30})
plt.rcParams.update({'font.size': 60})
plt.title("Top 10 rated movies listed by Directors")
# Out:
# Text(0.5, 1.0, 'Top 10 rated movies listed by Directors')

# %%
## Display Top 10 Highest Revenue Movie Titles

top10_rev = movies_df.nlargest(10, 'revenue')[['original_title', 'revenue']].set_index('original_title')
top10_rev
# Out:
#                                                    revenue
# original_title
# Avatar                                        2.781506e+09
# Star Wars: The Force Awakens                  2.068178e+09
# Titanic                                       1.845034e+09
# The Avengers                                  1.519558e+09
# Jurassic World                                1.513529e+09
# Furious 7                                     1.506249e+09
# Avengers: Age of Ultron                       1.405036e+09
# Harry Potter and the Deathly Hallows: Part 2  1.327818e+09
# Frozen                                        1.274219e+09
# Iron Man 3                                    1.215440e+09

# %%
sns.barplot(x='revenue', y = top10_rev.index, data = top10_rev)
plt.title ("Top Highest Revenue Movie Titles")
# Out:
# Text(0.5, 1.0, 'Top Highest Revenue Movie Titles')

# %%
## Find Average Votes of Movies Year Wise 

movies_df.groupby('release_year')['vote_count'].mean().sort_values(ascending = False)
# Out:
# release_year
# 1972    3970.000000
# 1977    2353.500000
# 1980    2041.000000
# 1985    2028.500000
# 2013    1651.261538
# 1982    1579.000000
# 2012    1531.852273
# 2014    1524.085714
# 1984    1475.250000
# 1997    1395.375000
# 2015    1322.021505
# 1999    1310.500000
# 2001    1276.222222
# 1995    1258.125000
# 1989    1256.000000
# 1990    1162.500000
# 2002    1143.083333
# 1979    1043.250000
# 1993     948.285714
# 1975     948.000000
# 2003     934.666667
# 1998     874.272727
# 1991     873.500000
# 1994     871.200000
# 2004     832.534884
# 1983     778.000000
# 2008     751.353659
# 2010     739.121212
# 2009     722.534483
# 2011     714.839744
# 1973     703.000000
# 1981     644.333333
# 2007     641.836957
# 1992     638.400000
# 2005     591.235294
# 2006     576.250000
# 1962     560.000000
# 1996     558.692308
# 2000     538.000000
# 1963     458.000000
# 1978     376.000000
# 1987     362.500000
# 1964     347.000000
# 1986     347.000000
# ...

# %%
## Does the votes affect the revenue - lets find out 

sns.scatterplot(x= 'vote_average', y = "revenue", data = movies_df, s=200)

# findings : once the votes are high, the revenue is just as high.
# Out:
# <AxesSubplot: xlabel='vote_average', ylabel='revenue'>

# %%
movies_df['genres']
# Out:
# 0       Action|Adventure|Science Fiction|Thriller
# 1       Action|Adventure|Science Fiction|Thriller
# 2              Adventure|Science Fiction|Thriller
# 3        Action|Adventure|Science Fiction|Fantasy
# 4                           Action|Crime|Thriller
#                           ...
# 1282                    Adventure|Action|Thriller
# 1283                    Adventure|Action|Thriller
# 1284                    Adventure|Action|Thriller
# 1285                              Horror|Thriller
# 1286                                       Comedy
# Name: genres, Length: 1287, dtype: object

# %%
## let's find the number of action movies 
## len is to get length
len(movies_df[movies_df['genres'].str.contains('Action', case = False)])
# Out:
# 415

# %%
## Let's find unique values from genres 
# lets split genres 

list = []
for value in movies_df['genres']:
   list.append(value.split('|'))

# %%
## convert this 2d list into a simple one dimension list 

one_dim = []
for item in list:
    for item1 in item: 
        one_dim.append(item1)

# %%
one_dim
# Out:
# ['Action',
#  'Adventure',
#  'Science Fiction',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Science Fiction',
#  'Thriller',
#  'Adventure',
#  'Science Fiction',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Science Fiction',
#  'Fantasy',
#  'Action',
#  'Crime',
#  'Thriller',
#  'Western',
#  'Drama',
#  'Adventure',
#  'Thriller',
#  'Science Fiction',
#  'Action',
#  'Thriller',
#  'Adventure',
#  'Drama',
#  'Adventure',
#  'Science Fiction',
#  'Family',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Comedy',
#  'Animation',
#  'Family',
#  'Action',
#  'Adventure',
#  'Crime',
#  'Science Fiction',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Science Fiction',
#  'Action',
#  'Comedy',
#  'Science Fiction',
#  'Action',
#  'Adventure',
#  'Science Fiction',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Western',
#  'Crime',
#  'Action',
#  'Thriller',
#  'Science Fiction',
#  'Action',
#  'Adventure',
#  'War',
#  'Adventure',
#  'Science Fiction',
# ...

# %%
## let's find the unique values
## create emoty list 

uni_list = []
for item in one_dim:
    if item not in uni_list:
        uni_list.append(item)

# %%
uni_list
# Out:
# ['Action',
#  'Adventure',
#  'Science Fiction',
#  'Thriller',
#  'Fantasy',
#  'Crime',
#  'Western',
#  'Drama',
#  'Family',
#  'Animation',
#  'Comedy',
#  'Mystery',
#  'War',
#  'Romance',
#  'History',
#  'Horror',
#  'Music',
#  'Documentary',
#  'Foreign']

# %%
## How many films of each genre were made?
#


one_dim = []
for item in list:
    for item1 in item: 
        one_dim.append(item1)

# %%
from collections import Counter

## keeps count on collectives

# %%
Counter(one_dim)
# Out:
# Counter({'Action': 415,
#          'Adventure': 297,
#          'Science Fiction': 209,
#          'Thriller': 399,
#          'Fantasy': 154,
#          'Crime': 193,
#          'Western': 13,
#          'Drama': 535,
#          'Family': 163,
#          'Animation': 108,
#          'Comedy': 414,
#          'Mystery': 98,
#          'War': 32,
#          'Romance': 196,
#          'History': 35,
#          'Horror': 139,
#          'Music': 38,
#          'Documentary': 15,
#          'Foreign': 1})

# %%
Counter(movies_df['popularity_level'])
# Out:
# Counter({'High': 322,
#          'Moderately High': 321,
#          'Medium': 322,
#          'Low': 321,
#          nan: 1})
